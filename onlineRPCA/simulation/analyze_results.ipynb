# %%
# analyze the results from simulation 4

import pickle

# %%
with open('result/all_results_sim4_online_v2.pickle','rb') as f:
    results_dict = pickle.load(f)
    
print(results_dict.keys())
# Out:
# dict_keys(['r1_rho1', 'r1_rho2', 'r2_rho1', 'r2_rho2', 'r3_rho1', 'r3_rho2', 'pms'])

# %%
results_dict['pms']
# Out:
# {'method': 'online',
#  'm': 400,
#  'n': 3000,
#  'rvec': [[10, 10, 10], [50, 50, 50], [10, 50, 25]],
#  'rho': [0.01, 0.1],
#  'n_p': 250,
#  'r0': 5,
#  'nrep': 50,
#  'seed': 12345,
#  'burnin': 200,
#  'win_size': 200,
#  'track_cp_burnin': 200,
#  'n_check_cp': 20,
#  'alpha': 0.01,
#  'proportion': 0.5,
#  'n_positive': 3,
#  'min_test_size': 100,
#  'tolerance_num': 0,
#  'factor': 1}

# %%
results_dict['r3_rho1']
# Out:
# {'result': [{'stoc_rpca':          t   error_L   error_S  false_S
#    0        1  0.946418  0.035156       34
#    1        2  0.759111  0.026393      114
#    2        3  0.740785  0.026929      146
#    3        4  0.658298  0.022992      184
#    4        5  0.594642  0.020466      215
#    ...    ...       ...       ...      ...
#    2995  2996  0.924458  0.045422   306046
#    2996  2997  0.924469  0.045423   306141
#    2997  2998  0.924496  0.045426   306324
#    2998  2999  0.924519  0.045419   306487
#    2999  3000  0.924535  0.045426   306655
#
#    [3000 rows x 4 columns],
#    'omwrpca':          t   error_L   error_S  false_S
#    0        1  0.927827  0.019884        0
#    1        2  0.548285  0.008772        0
#    2        3  0.472276  0.010209        0
#    3        4  0.419247  0.010610        0
#    4        5  0.377467  0.010201        0
#    ...    ...       ...       ...      ...
#    2995  2996  0.780154  0.036663   244778
# ...
